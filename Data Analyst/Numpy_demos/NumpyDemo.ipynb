# %% [markdown]
# # Numpy Demo

# %%
import numpy as np

# %%
arr1= np.array([1,2,3,4,5,6,7])
arr2= np.array([8,9,10,11,12,13,14])

# %%
arr1
# Out:
# array([1, 2, 3, 4, 5, 6, 7])

# %%
arr2
# Out:
# array([ 8,  9, 10, 11, 12, 13, 14])

# %%
arr3=arr1+arr2
arr3
# Out:
# array([ 9, 11, 13, 15, 17, 19, 21])

# %%
arr4=np.array([1,2,3,4,True,False])

# %%
arr4
# Out:
# array([1, 2, 3, 4, 1, 0])

# %%
# %%time
list1=[x for x in range(1,5001)]
list2=[x for x in range(5001,10001)]
list3=[]
for i, j in zip(list1,list2):
    list3.append(i+j)
# Out:
# CPU times: total: 0 ns
# Wall time: 3.1 ms

# %%
# %%time
arr1=np.array([x for x in range(1,5001)])
arr2=np.array([x for x in range(5001,10001)])
arr3=arr1+arr2
# Out:
# CPU times: total: 0 ns
# Wall time: 2.51 ms

# %%
arr5=np.array([1,2,3,"no", True ,None])
arr5
# Out:
# array([1, 2, 3, 'no', True, None], dtype=object)

# %% [markdown]
# ### check size list and array(numpy)

# %%
list1=[1,2,3,4,5]

# %%
import sys
sys.getsizeof(list1[0]) * len(list1)
# Out:
# 140

# %%
arr6= np.array([1,2,3,4,5])

# %%
arr6.itemsize*arr6.size
# Out:
# 40

# %% [markdown]
# ## pad

# %%
arr1=np.array([1,2,3,4])
arr2=np.array([4,5,6])

# %%
np.pad(arr2, (0,7))
# Out:
# array([4, 5, 6, 0, 0, 0, 0, 0, 0, 0])
