# %% [markdown]
# ###### create a function that return exponation value

# %%
def exponantial(a,b):
    value=a
    for _ in range(b-1):
        value*=a
    return value

# %%
exponantial(10,2)
# Out:
# 100

# %%
v1=int(input("Enter base value"))
v2=int(input("Enter Exponantial value"))
exponantial(v1,v2)
# Out:
# Enter base value 12
# Enter Exponantial value 4
# 20736
