# %% [markdown]
# # demo

# %% [markdown]
# ## variable

# %%
a=10
b=20
c=a+b
c
# Out:
# 30

# %%
str1="anaconda"

# %%
str2="deverconda"

# %%
str3=str1+" + "+ str2

# %%
str3
# Out:
# 'anaconda + deverconda'

# %% [markdown]
# ### program terminated
