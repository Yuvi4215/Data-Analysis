# %% [markdown]
# # Pandas Data Cleaning – Complete Step-by-Step Notebook
#
# This notebook demonstrates **end-to-end data cleaning using Pandas** for Data Analysis.
#
# ---

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1. Load Sample Dataset

# %%
data = {
    "Order_ID": [1001,1002,1003,1004,1005,1005],
    "Customer": ["Alice","Bob","Charlie",None,"Eve","Eve"],
    "Category": ["Electronics","Electronics","Furniture","Furniture","Electronics","Electronics"],
    "Price": [800,500,None,250,800,800],
    "Quantity": [2,1,4,1,None,None],
    "Order_Date": ["2024-01-01","2024-01-02","2024-01-03","invalid","2024-01-05","2024-01-05"]
}
df = pd.DataFrame(data)
df
# Out:
#    Order_ID Customer     Category  Price  Quantity  Order_Date
# 0      1001    Alice  Electronics  800.0       2.0  2024-01-01
# 1      1002      Bob  Electronics  500.0       1.0  2024-01-02
# 2      1003  Charlie    Furniture    NaN       4.0  2024-01-03
# 3      1004     None    Furniture  250.0       1.0     invalid
# 4      1005      Eve  Electronics  800.0       NaN  2024-01-05
# 5      1005      Eve  Electronics  800.0       NaN  2024-01-05

# %% [markdown]
# ## 2. Initial Inspection

# %%
df.head()
df.info()
df.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Order_ID    6 non-null      int64
#  1   Customer    5 non-null      object
#  2   Category    6 non-null      object
#  3   Price       5 non-null      float64
#  4   Quantity    4 non-null      float64
#  5   Order_Date  6 non-null      object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 420.0+ bytes
#            Order_ID Customer     Category       Price  Quantity  Order_Date
# count      6.000000        5            6    5.000000  4.000000           6
# unique          NaN        4            2         NaN       NaN           5
# top             NaN      Eve  Electronics         NaN       NaN  2024-01-05
# freq            NaN        2            4         NaN       NaN           2
# mean    1003.333333      NaN          NaN  630.000000  2.000000         NaN
# std        1.632993      NaN          NaN  248.997992  1.414214         NaN
# min     1001.000000      NaN          NaN  250.000000  1.000000         NaN
# 25%     1002.250000      NaN          NaN  500.000000  1.000000         NaN
# 50%     1003.500000      NaN          NaN  800.000000  1.500000         NaN
# 75%     1004.750000      NaN          NaN  800.000000  2.500000         NaN
# max     1005.000000      NaN          NaN  800.000000  4.000000         NaN

# %% [markdown]
# ## 3. Missing Values Detection

# %%
(df.isnull().sum() / len(df)) * 100
# Out:
# Order_ID      0.0
# Customer      0.0
# Category      0.0
# Price         0.0
# Quantity      0.0
# Order_Date    0.0
# dtype: float64

# %% [markdown]
# ## 4. Remove Missing Data

# %%
df_drop_rows = df.dropna()
df_drop_cols = df.dropna(axis=1)

# %% [markdown]
# ## 5. Fill Missing Values

# %%
df['Price'] = df['Price'].fillna(df['Price'].median())
df['Quantity'] = df['Quantity'].fillna(df['Quantity'].mean())
df['Customer'] = df['Customer'].fillna(df['Customer'].mode()[0])
df
# Out:
#    Order_ID Customer     Category  Price  Quantity  Order_Date
# 0      1001    Alice  Electronics  800.0       2.0  2024-01-01
# 1      1002      Bob  Electronics  500.0       1.0  2024-01-02
# 2      1003  Charlie    Furniture  800.0       4.0  2024-01-03
# 3      1004      Eve    Furniture  250.0       1.0     invalid
# 4      1005      Eve  Electronics  800.0       2.0  2024-01-05
# 5      1005      Eve  Electronics  800.0       2.0  2024-01-05

# %% [markdown]
# ## 6. Group-wise Fill

# %%
df['Price'] = df.groupby('Category')['Price'].transform(lambda x: x.fillna(x.mean()))

# %% [markdown]
# ## 7. Data Type Fixing

# %%
df['Order_Date'] = pd.to_datetime(df['Order_Date'], errors='coerce')
df.dtypes

# %% [markdown]
# ## 8. Duplicate Handling

# %%
df.duplicated().sum()
df = df.drop_duplicates()

# %% [markdown]
# ## 9. Text Cleaning

# %%
df['Customer'] = df['Customer'].str.strip().str.title()

# %% [markdown]
# ## 10. Column Renaming

# %%
df.rename(columns={'Order_ID':'order_id','Order_Date':'order_date'}, inplace=True)
df.columns

# %% [markdown]
# ## 11. Final Validation

# %%
df.isnull().sum()
df.info()
df

# %% [markdown]
# ## 12. Export Clean Data

# %%
df.to_csv("clean_data.csv", index=False)
