# %%
import pandas as pd

# %%
emp=pd.DataFrame({"eid":[101,102,103,104,105],
                            "name":["Ajay","Yuvi","Sunny","Abhi","Vaani"],
                  "salary":[185000,25000,20000,12000,195000]})

# %%
emp
# Out:
#    eid   name  salary
# 0  101   Ajay  185000
# 1  102   Yuvi   25000
# 2  103  Sunny   20000
# 3  104   Abhi   12000
# 4  105  Vaani  195000

# %%
dept_detailes=pd.DataFrame({"intake":[120, 60,120,60],
                            "admitted":[114,54,110,45],
                           }, index=["Mechanical","Electrical","Civil","Chemical"])

# %%
dept_detailes
# Out:
#             intake  admitted
# Mechanical     120       114
# Electrical      60        54
# Civil          120       110
# Chemical        60        45

# %% [markdown]
# ### Add column or row

# %%
dept_detailes["vaccant"]=dept_detailes["intake"]-dept_detailes["admitted"]

# %%
dept_detailes
# Out:
#             intake  admitted  vaccant
# Mechanical     120       114        6
# Electrical      60        54        6
# Civil          120       110       10
# Chemical        60        45       15

# %%
emp["address"]=["gurugram","pune","solapur","solapur","solapur"]

# %%
emp
# Out:
#    eid   name  salary   address
# 0  101   Ajay  185000  gurugram
# 1  102   Yuvi   25000      pune
# 2  103  Sunny   20000   solapur
# 3  104   Abhi   12000   solapur
# 4  105  Vaani  195000   solapur

# %%
emp.loc[emp.shape[0]]=[106,"isha",190000,"kanpur"]

# %%
emp
# Out:
#    eid   name  salary   address
# 0  101   Ajay  185000  gurugram
# 1  102   Yuvi   25000      pune
# 2  103  Sunny   20000   solapur
# 3  104   Abhi   12000   solapur
# 4  105  Vaani  195000   solapur
# 5  106   isha  190000    kanpur

# %%
emp["gender"]=["M","M","M","M","F","F"]

# %%
emp
# Out:
#    eid   name  salary   address gender
# 0  101   Ajay  185000  gurugram      M
# 1  102   Yuvi   25000      pune      M
# 2  103  Sunny   20000   solapur      M
# 3  104   Abhi   12000   solapur      M
# 4  105  Vaani  195000   solapur      F
# 5  106   isha  190000    kanpur      F

# %%
student=pd.DataFrame({"rollno":[1, 2,3,4],
                            "name":["jai","vijay","sanjay","digvijay"],
                           })

# %%
student
# Out:
#    rollno      name
# 0       1       jai
# 1       2     vijay
# 2       3    sanjay
# 3       4  digvijay

# %%
student["gender"]=["M","M","M","M"]

# %%
student["marks"]=[78,88,72,52]

# %%
student
# Out:
#    rollno      name gender  marks
# 0       1       jai      M     78
# 1       2     vijay      M     88
# 2       3    sanjay      M     72
# 3       4  digvijay      M     52

# %% [markdown]
# ### Drop column or row

# %%
student.drop("gender", axis=1)
# Out:
#    rollno      name  marks
# 0       1       jai     78
# 1       2     vijay     88
# 2       3    sanjay     72
# 3       4  digvijay     52

# %%
student
# Out:
#    rollno      name gender  marks
# 0       1       jai      M     78
# 1       2     vijay      M     88
# 2       3    sanjay      M     72
# 3       4  digvijay      M     52

# %%
student.drop("gender", axis=1,inplace=True)
student
# Out:
#    rollno      name  marks
# 0       1       jai     78
# 1       2     vijay     88
# 2       3    sanjay     72
# 3       4  digvijay     52

# %%
student.drop(3,inplace=True)
student
# Out:
#    rollno    name  marks
# 0       1     jai     78
# 1       2   vijay     88
# 2       3  sanjay     72

# %%
student.drop(["rollno","marks"],axis=1, inplace=True)
student
# Out:
#      name
# 0     jai
# 1   vijay
# 2  sanjay
