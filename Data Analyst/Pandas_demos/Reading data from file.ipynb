# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("../DataSets/Iris.csv")

# %%
data.shape
# Out:
# (150, 5)

# %%
data.columns
# Out:
# Index(['Sepal_Length', 'Sepal_Width', 'Petal_Length', 'Petal_Width',
#        'Species'],
#       dtype='object')

# %%
data.head()
# Out:
#    Sepal_Length  Sepal_Width  Petal_Length  Petal_Width Species
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
data.tail()
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width    Species
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica

# %%
data.tail(15)
# Out:
#      Sepal_Length  Sepal_Width  Petal_Length  Petal_Width    Species
# 135           7.7          3.0           6.1          2.3  Virginica
# 136           6.3          3.4           5.6          2.4  Virginica
# 137           6.4          3.1           5.5          1.8  Virginica
# 138           6.0          3.0           4.8          1.8  Virginica
# 139           6.9          3.1           5.4          2.1  Virginica
# 140           6.7          3.1           5.6          2.4  Virginica
# 141           6.9          3.1           5.1          2.3  Virginica
# 142           5.8          2.7           5.1          1.9  Virginica
# 143           6.8          3.2           5.9          2.3  Virginica
# 144           6.7          3.3           5.7          2.5  Virginica
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# ...

# %%
data.isna().sum()
# Out:
# Sepal_Length    0
# Sepal_Width     0
# Petal_Length    0
# Petal_Width     0
# Species         0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sepal_Length  150 non-null    float64
#  1   Sepal_Width   150 non-null    float64
#  2   Petal_Length  150 non-null    float64
#  3   Petal_Width   150 non-null    float64
#  4   Species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
data.nunique()
# Out:
# Sepal_Length    35
# Sepal_Width     23
# Petal_Length    43
# Petal_Width     22
# Species          3
# dtype: int64

# %%
data["Species"].nunique()
# Out:
# 3

# %%
data["Species"].unique()
# Out:
# array(['Setosa', 'Versicolor', 'Virginica'], dtype=object)

# %%
data["Species"].value_counts()
# Out:
# Species
# Setosa        50
# Versicolor    50
# Virginica     50
# Name: count, dtype: int64

# %%
data[data["Species"].isna()]
# Out:
# Empty DataFrame
# Columns: [Sepal_Length, Sepal_Width, Petal_Length, Petal_Width, Species]
# Index: []

# %%
data=pd.read_csv("../DataSets/cars93.csv")

# %%
data
# Out:
#    Manufacturer    Model     Type  Price  MPG.city             AirBags  \
# 0         Acura  Integra    Small   15.9        25         Driver only
# 1         Acura   Legend  Midsize   33.9        18  Driver & Passenger
# 2          Audi       90  Compact   29.1        20         Driver only
# 3          Audi      100  Midsize   37.7        19  Driver & Passenger
# 4           BMW     535i  Midsize   30.0        22         Driver only
# ..          ...      ...      ...    ...       ...                 ...
# 88   Volkswagen  Eurovan      Van   19.7        17  Driver & Passenger
# 89   Volkswagen   Passat  Compact   20.0        21  Driver & Passenger
# 90   Volkswagen  Corrado   Sporty   23.3        18  Driver & Passenger
# 91        Volvo      240  Compact   22.7        21         Driver only
# 92        Volvo      850  Midsize   26.7        20  Driver & Passenger
#
#     Horsepower  Passengers  Rear.seat.room  Luggage.room
# 0          140           5            26.5          11.0
# ...

# %%
data.isna().sum()
# Out:
# Manufacturer       0
# Model              0
# Type               0
# Price              0
# MPG.city           0
# AirBags           14
# Horsepower         0
# Passengers         0
# Rear.seat.room     2
# Luggage.room      11
# dtype: int64

# %%
data.head()
# Out:
#   Manufacturer    Model     Type  Price  MPG.city             AirBags  \
# 0        Acura  Integra    Small   15.9        25         Driver only
# 1        Acura   Legend  Midsize   33.9        18  Driver & Passenger
# 2         Audi       90  Compact   29.1        20         Driver only
# 3         Audi      100  Midsize   37.7        19  Driver & Passenger
# 4          BMW     535i  Midsize   30.0        22         Driver only
#
#    Horsepower  Passengers  Rear.seat.room  Luggage.room
# 0         140           5            26.5          11.0
# 1         200           5            30.0          15.0
# 2         172           5            28.0          14.0
# 3         172           6            31.0          17.0
# 4         208           4            27.0          13.0

# %%
data.tail()
# Out:
#    Manufacturer    Model     Type  Price  MPG.city             AirBags  \
# 88   Volkswagen  Eurovan      Van   19.7        17  Driver & Passenger
# 89   Volkswagen   Passat  Compact   20.0        21  Driver & Passenger
# 90   Volkswagen  Corrado   Sporty   23.3        18  Driver & Passenger
# 91        Volvo      240  Compact   22.7        21         Driver only
# 92        Volvo      850  Midsize   26.7        20  Driver & Passenger
#
#     Horsepower  Passengers  Rear.seat.room  Luggage.room
# 88         109           7            34.0           NaN
# 89         134           5            31.5          14.0
# 90         178           4            26.0          15.0
# 91         114           5            29.5          14.0
# 92         168           5            30.0          15.0

# %%
row_to_delete=data[data["Luggage.room"].isna()].index

# %%
data.drop(row_to_delete)
# Out:
#    Manufacturer    Model     Type  Price  MPG.city             AirBags  \
# 0         Acura  Integra    Small   15.9        25         Driver only
# 1         Acura   Legend  Midsize   33.9        18  Driver & Passenger
# 2          Audi       90  Compact   29.1        20         Driver only
# 3          Audi      100  Midsize   37.7        19  Driver & Passenger
# 4           BMW     535i  Midsize   30.0        22         Driver only
# ..          ...      ...      ...    ...       ...                 ...
# 87   Volkswagen      Fox    Small    9.1        25                 NaN
# 89   Volkswagen   Passat  Compact   20.0        21  Driver & Passenger
# 90   Volkswagen  Corrado   Sporty   23.3        18  Driver & Passenger
# 91        Volvo      240  Compact   22.7        21         Driver only
# 92        Volvo      850  Midsize   26.7        20  Driver & Passenger
#
#     Horsepower  Passengers  Rear.seat.room  Luggage.room
# 0          140           5            26.5          11.0
# ...

# %%
data[data["Luggage.room"].isna()]
# Out:
#    Manufacturer       Model    Type  Price  MPG.city             AirBags  \
# 15    Chevrolet  Lumina_APV     Van   16.3        18         Driver only
# 16    Chevrolet       Astro     Van   16.6        15                 NaN
# 18    Chevrolet    Corvette  Sporty   38.0        17         Driver only
# 25        Dodge     Caravan     Van   19.0        17         Driver only
# 35         Ford    Aerostar     Van   19.9        15         Driver only
# 55        Mazda         MPV     Van   19.1        18  Driver & Passenger
# 56        Mazda        RX-7  Sporty   32.5        17         Driver only
# 65       Nissan       Quest     Van   19.1        17                 NaN
# 69   Oldsmobile  Silhouette     Van   19.5        18  Driver & Passenger
# 86       Toyota      Previa     Van   22.7        18         Driver only
# 88   Volkswagen     Eurovan     Van   19.7        17  Driver & Passenger
#
#     Horsepower  Passengers  Rear.seat.room  Luggage.room
# ...

# %%
data
# Out:
#    Manufacturer    Model     Type  Price  MPG.city             AirBags  \
# 0         Acura  Integra    Small   15.9        25         Driver only
# 1         Acura   Legend  Midsize   33.9        18  Driver & Passenger
# 2          Audi       90  Compact   29.1        20         Driver only
# 3          Audi      100  Midsize   37.7        19  Driver & Passenger
# 4           BMW     535i  Midsize   30.0        22         Driver only
# ..          ...      ...      ...    ...       ...                 ...
# 88   Volkswagen  Eurovan      Van   19.7        17  Driver & Passenger
# 89   Volkswagen   Passat  Compact   20.0        21  Driver & Passenger
# 90   Volkswagen  Corrado   Sporty   23.3        18  Driver & Passenger
# 91        Volvo      240  Compact   22.7        21         Driver only
# 92        Volvo      850  Midsize   26.7        20  Driver & Passenger
#
#     Horsepower  Passengers  Rear.seat.room  Luggage.room
# 0          140           5            26.5          11.0
# ...
