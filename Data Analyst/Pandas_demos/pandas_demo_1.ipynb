# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Series: Collection of labbed data

# %%
s1=pd.Series([1,2,3,4])
s1
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
s1=pd.Series([1,2,3,4], index=['a','b','c','A'])
s1
# Out:
# a    1
# b    2
# c    3
# A    4
# dtype: int64

# %% [markdown]
# #### Different ways to create series

# %%
s1=pd.Series(np.random.randint(1,20,4))
s1
# Out:
# 0    17
# 1    12
# 2     2
# 3     8
# dtype: int32

# %%
s1.index=["A","B","C","D"]
s1
# Out:
# A    17
# B    12
# C     2
# D     8
# dtype: int32

# %% [markdown]
# ##### accesing element using userdefined index

# %%
s1["A"]
# Out:
# np.int32(17)

# %% [markdown]
# ##### accesing element using inbuild-index(start from 0 to ...)

# %%
s1.iloc[2]
# Out:
# np.int32(2)

# %%
toppers=pd.Series({"Mech": 98, "Civil": 40, "IT":41})
toppers
# Out:
# Mech     98
# Civil    40
# IT       41
# dtype: int64

# %% [markdown]
# #### Operation on Series

# %%
s1=pd.Series([10,20,30,40], index=["A","B","C","D"])
s2=pd.Series([1,2,3,4],index=["E","F","G","H"])
s1+s2
# Out:
# A   NaN
# B   NaN
# C   NaN
# D   NaN
# E   NaN
# F   NaN
# G   NaN
# H   NaN
# dtype: float64

# %%
s1=pd.Series([10,20,30,40], index=["A","B","C","D"])
s2=pd.Series([1,2,3,4],index=["C","D","E","F"])
s1+s2
# Out:
# A     NaN
# B     NaN
# C    31.0
# D    42.0
# E     NaN
# F     NaN
# dtype: float64

# %%
s1=pd.Series([10,20,30,40])
s2=pd.Series([1,2,3,4])
s1+s2
# Out:
# 0    11
# 1    22
# 2    33
# 3    44
# dtype: int64

# %%
s2[s2%2==0]
# Out:
# 1    2
# 3    4
# dtype: int64
