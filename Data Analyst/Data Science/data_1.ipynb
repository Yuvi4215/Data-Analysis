# %%
import pandas as pd

# %%
data=pd.Series([23,80,80,12,90,30,22,66,90,65,25,44,15,28])

# %%
data.mean()
# Out:
# np.float64(47.857142857142854)

# %%
data.median()
# Out:
# np.float64(37.0)

# %%
data.mode()
# Out:
# 0    80
# 1    90
# dtype: int64

# %%
data=pd.read_csv("../DataSets/Data Science/shoe_sales.csv")

# %%
data.head()
# Out:
#        date   brand  sold_qty
# 0  9/1/2023    Nike      24.0
# 1  9/1/2023  Adidas      14.0
# 2  9/2/2023    Nike      21.0
# 3  9/2/2023  Adidas      12.0
# 4  9/3/2023    Nike      18.0

# %%
data.sample(5)
# Out:
#          date   brand  sold_qty
# 52  9/27/2023    Nike      22.0
# 41  9/21/2023  Adidas      18.0
# 31  9/16/2023  Adidas      14.0
# 24  9/13/2023    Nike      16.0
# 13   9/7/2023  Adidas      16.0

# %%
data["brand"].unique()
# Out:
# array(['Nike', 'Adidas'], dtype=object)

# %%
data["brand"].value_counts()
# Out:
# brand
# Nike      30
# Adidas    30
# Name: count, dtype: int64

# %%
data.isna().sum()
# Out:
# date        0
# brand       0
# sold_qty    2
# dtype: int64

# %%
data[data["sold_qty"].isna()]
# Out:
#          date brand  sold_qty
# 32  9/17/2023  Nike       NaN
# 48  9/25/2023  Nike       NaN

# %%
data[data["brand"]=="Nike"]["sold_qty"].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 data[data["brand"]=="Nike"]["sold_qty"].mean()(":.2f")
#
# TypeError: 'numpy.float64' object is not callable

# %%
data["sold_qty"].fillna(data[data["brand"]=="Nike"]["sold_qty"].mean(),inplace=True)
# Out:
# C:\Users\Ajay Varma\AppData\Local\Temp\ipykernel_22344\344849540.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data["sold_qty"].fillna(data[data["brand"]=="Nike"]["sold_qty"].mean(),inplace=True)

# %%
data.isna().sum()
# Out:
# date        0
# brand       0
# sold_qty    0
# dtype: int64

# %%
data.groupby("brand")["sold_qty"].mean()
# Out:
# brand
# Adidas    34.800000
# Nike      19.642857
# Name: sold_qty, dtype: float64
