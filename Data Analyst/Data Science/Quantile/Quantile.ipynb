# %% [markdown]
# ### Quantile

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data= pd.Series([10,25,35,49,51,52,60,62,70,98])

# %%
q4=data.quantile(1.0)
q4
# Out:
# np.float64(98.0)

# %%
q3=data.quantile(0.75)
q3
# Out:
# np.float64(61.5)

# %%
q2=data.quantile(0.50)
q2
# Out:
# np.float64(51.5)

# %%
q1=data.quantile(0.25)
q1
# Out:
# np.float64(38.5)

# %%
data.describe()
# Out:
# count    10.000000
# mean     51.200000
# std      24.471298
# min      10.000000
# 25%      38.500000
# 50%      51.500000
# 75%      61.500000
# max      98.000000
# dtype: float64

# %%
data1=pd.read_csv("../../DataSets/Data_Science/shoe_sales.csv")

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      60 non-null     object
#  1   brand     60 non-null     object
#  2   sold_qty  58 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.5+ KB

# %%
data1.isna().sum()
# Out:
# date        0
# brand       0
# sold_qty    2
# dtype: int64

# %%
data1["sold_qty"]
# Out:
# 0      24.0
# 1      14.0
# 2      21.0
# 3      12.0
# 4      18.0
# 5      11.0
# 6      22.0
# 7      13.0
# 8      20.0
# 9      10.0
# 10     23.0
# 11     15.0
# 12     19.0
# 13     16.0
# 14     17.0
# 15      8.0
# 16     25.0
# 17     17.0
# 18     14.0
# 19      7.0
# 20     23.0
# 21      9.0
# 22     19.0
# 23    689.0
# 24     16.0
# 25     11.0
# 26     22.0
# 27     13.0
# 28     17.0
# 29     10.0
# 30     21.0
# 31     14.0
# 32      NaN
# 33      8.0
# 34     18.0
# 35     15.0
# 36     15.0
# 37      7.0
# 38     24.0
# 39     19.0
# 40     24.0
# 41     18.0
# 42     16.0
# 43     12.0
# 44     20.0
# 45     11.0
# 46     15.0
# 47     14.0
# 48      NaN
# 49     10.0
# 50     19.0
# 51      9.0
# 52     22.0
# 53     13.0
# 54     21.0
# 55     15.0
# 56     17.0
# 57      8.0
# 58     18.0
# 59     16.0
# Name: sold_qty, dtype: float64

# %%
data1["sold_qty"]=data1.groupby("brand")["sold_qty"].transform(lambda x:x.fillna(x.mean()))

# %%
sns.boxplot(data1["sold_qty"])
# Out:
# <Axes: ylabel='sold_qty'>

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      60 non-null     object
#  1   brand     60 non-null     object
#  2   sold_qty  60 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 1.5+ KB

# %%
data1.describe()
# Out:
#          sold_qty
# count   60.000000
# mean    27.221429
# std     87.018147
# min      7.000000
# 25%     12.750000
# 50%     16.000000
# 75%     19.732143
# max    689.000000

# %%
mean=data1["sold_qty"].mean()
std_val=data1["sold_qty"].std()
std_val
# Out:
# np.float64(87.01814668190964)

# %%
sns.histplot(x="sold_qty",data=data1,kde=True)
# Out:
# <Axes: xlabel='sold_qty', ylabel='Count'>
